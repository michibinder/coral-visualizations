# %%
import os
# from netCDF4 import Dataset
import numpy as np
import pandas as pd
import xarray as xr
from scipy import signal
import datetime

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.colors import BoundaryNorm, LogNorm
from matplotlib.ticker import MultipleLocator, FormatStrFormatter, AutoMinorLocator

plt.style.use('latex_default.mplstyle')

# %%
"""CORAL datasets"""
ds = xr.open_dataset("/export/data/malidar/tana/Southwave/v14combined/20180214-0114_T15Z900.nc", decode_times=False)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                 (value: 1, channels: 1, time: 46, altitude: 1600)
# Coordinates:
#   * time                    (time) uint32 5105000 5405000 ... 18305000 18605000
#   * altitude                (altitude) uint32 18 118 218 ... 159818 159918
# Dimensions without coordinates: value, channels
# Data variables: (12/20)
#     station_latitude        (value) float64 ...
#     station_longitude       (value) float64 ...
#     station_height          (value) uint32 ...
#     time_offset             (value) uint32 ...
#     altitude_offset         (value) uint32 ...
#     wavelength              (channels) float64 ...
#     ...                      ...
#     merge1_mean_diff        (time) float32 ...
#     merge2_top_bin          (time) uint32 ...
#     merge2_bottom_bin       (time) uint32 ...
#     merge2_mean_diff        (time) float32 ...
#     temperature             (time, altitude) float32 ...
#     temperature_err         (time, altitude) float32 ...
# ...

# %%
"""TELMA daily datasets"""
ds = xr.open_dataset("/export/data/malidar/tana/Southpole/v18daily/20230521-0331_T15Z900.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 246, altitude: 1600)
# Coordinates:
#   * time             (time) float64 0.0 3e+05 6e+05 ... 7.32e+07 7.35e+07
#   * altitude         (altitude) float64 2.856e+03 2.956e+03 ... 1.628e+05
# Data variables:
#     time_offset      float64 ...
#     temperature      (time, altitude) float64 ...
#     temperature_err  (time, altitude) float64 ...

# %%
ds = xr.open_dataset("output/coral/era5-profiles/20220617-2243-ml.nc")
ds
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/unstable-venv/lib/python3.11/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/miniforge3/envs/unstable-venv/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/export/data/ma-lidar-visualizations/output/coral/era5-profiles/20220617-2243-ml.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'a87906bb-5cba-4dad-a3ac-a67fb80e67e6']
#
# ...
